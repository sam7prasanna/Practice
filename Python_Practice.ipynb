# %%
a = [1,2,3,4,5]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Set - Removes duplicate & give unique value, automatically sort 

s = {1, 2, 3, 1, 8, 6, 2, 5}
s
for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 8

# %%
# list - Doesn't remove duplicate
a = [1,2,3,4,5,2,1,6]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 2
# 1
# 6

# %%
# tuple - Doesn't remove duplicate
b = (1, 3, 2, 5, 4, 3)
b
for i in b:
    print(i)
# Out:
# 1
# 3
# 2
# 5
# 4
# 3

# %%
str = "Python was"
  #    0123456789
print('value is "' + str[0:8:2] + '"')
print(str[::-1]) #reversing string
# Out:
# value is "Pto "
# saw nohtyP

# %%
print(str[::1]) #jumps 1 position from the start point
print(str[::2]) #jumps 2 position from the start point
print(str[::3])
# Out:
# Python was
# Pto a
# Ph s

# %%
lst = [1,2,3,4,5]
print(lst[2:5])
# Out:
# [3, 4, 5]

# %%
nlst = ["apple", "mango", "pineapple", "jackfruit", "tomato"]
print(nlst[3:5])
# Out:
# ['jackfruit', 'tomato']

# %%
nlst.reverse()
nlst.sort()
nlst
# Out:
# ['apple', 'mango', 'pineapple', 'jackfruit', 'tomato']

# %%
nlst[2] = "fruit"
nlst
# Out:
# ['apple', 'mango', 'fruit', 'jackfruit', 'tomato']

# %%
nlst.append("orange")
nlst
# Out:
# ['apple', 'mango', 'fruit', 'jackfruit', 'tomato', 'orange', 'orange']

# %%
nlst.remove("orange")
nlst
# Out:
# ['apple', 'mango', 'fruit', 'jackfruit', 'tomato', 'orange']

# %%
nlst.extend(["brinjal", "lemon"])
nlst
# Out:
# ['apple',
#  'mango',
#  'fruit',
#  'jackfruit',
#  'tomato',
#  'orange',
#  'brinjal',
#  'lemon']

# %%
nlst.insert(1, "citrus")
nlst
# Out:
# ['apple',
#  'citrus',
#  'mango',
#  'fruit',
#  'jackfruit',
#  'tomato',
#  'orange',
#  'brinjal',
#  'lemon']

# %%
nlst.pop()
nlst
# Out:
# ['apple',
#  'citrus',
#  'mango',
#  'fruit',
#  'jackfruit',
#  'tomato',
#  'orange',
#  'brinjal']

# %%
st = {"apple", "pineapple", "mango", "apple", "orange", "orange"}
st
# Out:
# {'apple', 'mango', 'orange', 'pineapple'}

# %%
st2 = {"orange", "mango", "orange", "pineapple"}
st2
# Out:
# {'mango', 'orange', 'pineapple'}

# %%
st2.add("lime")
st2
# Out:
# {'lime', 'mango', 'orange', 'pineapple'}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6, 7}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6, 7}
print(a.intersection(b))
# Out:
# {3, 4}

# %%
tpl1 = ("ravi", 25, "65DD1", "IT")
tpl2 = ("Chennai", "WFO")
print(tpl1 + tpl2)
# Out:
# ('ravi', 25, '65DD1', 'IT', 'Chennai', 'WFO')

# %%
dct = {"name":"kannan", "dept":"IT","ID":"65DD1"}
dct
# Out:
# {'name': 'kannan', 'dept': 'IT', 'ID': '65DD1'}

# %%
dct["dept"] = "Sales"
dct
# Out:
# {'name': 'kannan', 'dept': 'Sales', 'ID': '65DD1'}

# %%
dct["mode"] = "WFO"
dct
# Out:
# {'name': 'kannan', 'dept': 'Sales', 'ID': '65DD1', 'mode': 'WFO'}

# %%
dct.pop("mode")
dct
# Out:
# {'name': 'kannan', 'dept': 'Sales', 'ID': '65DD1'}

# %%
dct.values()
# Out:
# dict_values(['kannan', 'Sales', '65DD1'])

# %%
dct.items()
# Out:
# dict_items([('name', 'kannan'), ('dept', 'Sales'), ('ID', '65DD1')])

# %%
x = 5
for i in range(x):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0
while i<=5:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for I in [1, 3, 54, 66, 88, 103]:
	if I == 54:
		print("match found")
		break
	print("number found")
# Out:
# number found
# number found
# match found

# %%
for I in [1, 3, 54, 66, 88, 103]:
	if I == 54:
		print("match found")
		continue
	print("number found")
# Out:
# number found
# number found
# match found
# number found
# number found
# number found

# %%
st = "Python is great program"
txt = st.split()
txt
# count = len(st.split())
# print("Word Count:", count)
# Out:
# ['Python', 'is', 'great', 'program']

# %%
tt = "Python is simple and Python is powerful"
dct = {}
dct = tt.split()
# dct.update(txt)
dct
# Out:
# ['Python', 'is', 'simple', 'and', 'Python', 'is', 'powerful']

# %%
def greet(name):
    print("hello", name)
    return

greet("Prasanna")
# Out:
# hello Prasanna

# %%
def grind(grain):
    sp = grain.split()
    return

grind("rice ready")

# %%
def sq(x):
    c=x*x
    return c

sq(3)
# Out:
# 9

# %%
def sq(x):
    x*x
    return x

print("the value is", sq(3))
print("the vlaue is", sq(4))

# Here since the function sq is returning the 'x', the output came as the value is 3
# Out:
# the value is 3
# the vlaue is 4

# %%
c = lambda a : a + 2
c(6)

# Anonymous function that will not follow the conventional function format
# Out:
# 8

# %%
# lambda can be written without the arugument also
# The general syntax is lambda arguement : expression

d = lambda : "Greetings"
d()
# Out:
# 'Greetings'

# %%
# We can use two variables in lambda 
add = lambda a, b : a + b
add(3,5)
# Out:
# 8

# %%
round(3.1658744,2)

# syntax is round(number, no of digits to be rounded off)
# Out:
# 3.17

# %%
import math

# %%
math.ceil(3.2248)
# round off to the highest value
# Out:
# 4

# %%
# math.floor(3.213)
math.floor(3.668)
# round off to the lowest value
# Out:
# 3

# %%
math.pow(5,3)
# Out:
# 125.0

# %%
import random

# %%
random.randint(5,26)
# Out:
# 18

# %%
random.randrange(8,29,3)
# Out:
# 14

# %%
random.choice(["goat","lion","cheetah"])
# Out:
# 'goat'
